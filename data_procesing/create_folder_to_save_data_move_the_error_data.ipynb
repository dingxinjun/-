# %% [markdown]
# ### create folder
# ### 创建文件夹然后每个文件夹下面包括存储文件的子文件夹

# %%
import os
Folders = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12', '13',
               '14', '15', '16', '17', '18']
#创建文件夹
#创建子文件夹
##子文件夹
Sub_Folders=['summary_plot','rmse_ratio','nc_file','eval_monthly_streamflow_index','monthly_index']
##v1
# for dirName in Folders:
#     if not os.path.exists(dirName):
#         os.mkdir(dirName)
#         print("Directory " , dirName ,  " Created ")
        
#     else:    
#         print("Directory " , dirName ,  " already exists")
##v2 loop_folder
for dirName in Folders:
    if not os.path.exists(dirName):
        os.mkdir(dirName)
        print("Directory " , dirName ,  " Created ")
        for subdir in Sub_Folders:
            subdirname=os.path.join(dirName,subdir)
            if not os.path.exists(subdirname):
                os.mkdir(subdirname)
            else:
                print("Directory " , subdirname ,  " already exists")
            
        
    else:    
        print("Directory " , dirName ,  " already exists")
        for subdir in Sub_Folders:
            subdirname=os.path.join(dirName,subdir)
            if not os.path.exists(subdirname):
                os.mkdir(subdirname)
            else:
                print("Directory " , subdirname ,  " already exists")
# Out:
# Directory  01  already exists
# Directory  02  already exists
# Directory  03  already exists
# Directory  04  already exists
# Directory  05  already exists
# Directory  06  already exists
# Directory  07  already exists
# Directory  08  already exists
# Directory  09  already exists
# Directory  10  already exists
# Directory  11  already exists
# Directory  12  already exists
# Directory  13  already exists
# Directory  14  already exists
# Directory  15  already exists
# Directory  16  already exists
# Directory  17  already exists
# Directory  18  already exists

# %%
path=r"C:\F\all_basin\removed_data\after81_10"
import os 
os.chdir(path)
Folders = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12', '13',
               '14', '15', '16', '17', '18']
#创建文件夹
#创建子文件夹
##子文件夹
Sub_Folders=['80','84','86','89','all']
# Sub_Folders=Sub_Folders.reverse()
for dirName in Folders:
    if not os.path.exists(dirName):
        os.mkdir(dirName)
        print("Directory " , dirName ,  " Created ")
        for subdir in Sub_Folders:
            subdirname=os.path.join(dirName,subdir)
            if not os.path.exists(subdirname):
                os.mkdir(subdirname)
            else:
                print("Directory " , subdirname ,  " already exists")
            
        
    else:    
        print("Directory " , dirName ,  " already exists")
        for subdir in Sub_Folders:
            subdirname=os.path.join(dirName,subdir)
            if not os.path.exists(subdirname):
                os.mkdir(subdirname)
            else:
                print("Directory " , subdirname ,  " already exists")
# Out:
# Directory  01  already exists
# Directory  01\80  already exists
# Directory  01\84  already exists
# Directory  01\86  already exists
# Directory  01\89  already exists
# Directory  02  already exists
# Directory  02\80  already exists
# Directory  02\84  already exists
# Directory  02\86  already exists
# Directory  02\89  already exists
# Directory  03  already exists
# Directory  03\80  already exists
# Directory  03\84  already exists
# Directory  03\86  already exists
# Directory  03\89  already exists
# Directory  04  already exists
# Directory  04\80  already exists
# Directory  04\84  already exists
# Directory  04\86  already exists
# Directory  04\89  already exists
# Directory  05  already exists
# Directory  05\80  already exists
# Directory  05\84  already exists
# Directory  05\86  already exists
# Directory  05\89  already exists
# Directory  06  already exists
# Directory  06\80  already exists
# Directory  06\84  already exists
# Directory  06\86  already exists
# ...

# %%
# Sub_Folders=Sub_Folders[::-1]
Sub_Folders=['80','84','86','89']
print(Sub_Folders[::-1])
# Out:
# ['89', '86', '84', '80']

# %%
import pandas as pd
#start_date, end_date,率定时间 datelist就是data index
def is_date_in_list(start_date, end_date, date_list):
    """
    identify whether the date is in the list
    if date is out of range, print the prompt
    :param start_date: date, YYYY-MM
    :param end_date: date, YYYY-MM
    :param date_list: date series used for detection  # list
    :return: bool
    """
    date_list = pd.date_range(start=date_list[0], end=date_list[-1],freq='MS')
    if (start_date not in date_list) or (end_date not in date_list):
#         if language == 'English':
#             print('Date out of range!')
#         elif language == '中文':
        print('日期超出了范围！')
        return False
    else:
        return True
        print('数据日期正常')
Camel_path=r'C:\F\all_basin\camel_monthly'
for folder in Folders:
    #进入文件夹
    folder_path=os.path.join(Camel_path,folder)
#     print(folder_path)

# %%
from shutil import move
Camel_path=r'C:\F\all_basin\camel_monthly'
distrot=r'C:\F\all_basin\removed_data\after81_10'

count1=0
count2=0
count3=0
for folder in Folders:
    #进入文件夹
    folder_path=os.path.join(Camel_path,folder)
    print(folder_path)
    list_of_file = os.listdir(folder_path)
    list_of_file_name=[i[:-4] for i in list_of_file]
    for file in list_of_file:
        
        file_path=os.path.join(folder_path,file)
        #读取数据并且将其index的时间弄出来
        data=pd.read_csv(file_path, index_col=0)
        data.index = pd.to_datetime(data.index)
        condition =is_date_in_list('1982-10-01','2014-12-01',data.index)
        
        if condition:
            print('{}数据正常'.format(file))
            count1=count1+1
        else:
            print('{}数据ERROR'.format(file))
            count2=count2+1
            srcroot=file_path
            
            distroot=os.path.join(distrot,folder,'all')
            move(srcroot,distroot)
            count3=count3+1
            
print('正常数据：',count1,'不正常数据',count2,'第二次移除数据',count3)
# Out:
# C:\F\all_basin\camel_monthly\01
# 01013500monthly.csv数据正常
# 01022500monthly.csv数据正常
# 01030500monthly.csv数据正常
# 01031500monthly.csv数据正常
# 01047000monthly.csv数据正常
# 01052500monthly.csv数据正常
# 01054200monthly.csv数据正常
# 01055000monthly.csv数据正常
# 01057000monthly.csv数据正常
# 01073000monthly.csv数据正常
# 01078000monthly.csv数据正常
# 01118300monthly.csv数据正常
# 01121000monthly.csv数据正常
# 01123000monthly.csv数据正常
# 01134500monthly.csv数据正常
# 01137500monthly.csv数据正常
# 01139000monthly.csv数据正常
# 01139800monthly.csv数据正常
# 01142500monthly.csv数据正常
# 01144000monthly.csv数据正常
# 01162500monthly.csv数据正常
# 01169000monthly.csv数据正常
# 01170100monthly.csv数据正常
# 01181000monthly.csv数据正常
# 01187300monthly.csv数据正常
# 01195100monthlytime.csv数据正常
# 04296000monthly.csv数据正常
# C:\F\all_basin\camel_monthly\02
# 01013500monthly.csv数据正常
# 01022500monthly.csv数据正常
# 01030500monthly.csv数据正常
# 01031500monthly.csv数据正常
# 01047000monthly.csv数据正常
# 01052500monthly.csv数据正常
# 01054200monthly.csv数据正常
# 01055000monthly.csv数据正常
# ...

# %%
测试shulti移动文件

# %%
from shutil import move
srcroot=r'C:\F\all_basin\camel_monthly\02\01195100monthly.csv'
dstroot=r'C:\F\all_basin\removed_data\after81_10\02\all'
move(srcroot,dstroot)
# Out:
# 'C:\\F\\all_basin\\removed_data\\after81_10\\02\\all\\01195100monthly.csv'
